# %% [markdown]
# # Madhava series #
#
# In this noteboook, we will be using the Madhava series to find an approximation for  $\frac{\pi}{4}$. The Madhava series is a converging series so we will try see how accurate our value for $\frac{\pi}{4}$ gets as we compute more terms with a given tolerance[1]. The Madhava series is known as:
#
# $$
# \frac{\pi}{4} =\sum_{n=0}^\infty \frac{(−1)^n}{2n+1}
# $$

# %%
#First import our libraries

import numpy as np

#Then form our equation in a while loop


def madhava_series(tolerance):
    n = 1 
    value = 1
    newterm = tolerance*2
    
    while ((newterm**2)**.5) > tolerance:
        newterm = ((-1) ** n)/(2*n+1)
        print(f'pi/4 is {value}')
        print(f'Difference between actual value of pi/4 is {0.25*np.pi-value}') 
        value += newterm
        n += 1

# %%
pi_over_4 = madhava_series(1e-1)
# Out:
# pi/4 is 1
# Difference between actual value of pi/4 is -0.21460183660255172
# pi/4 is 0.6666666666666667
# Difference between actual value of pi/4 is 0.11873149673078154
# pi/4 is 0.8666666666666667
# Difference between actual value of pi/4 is -0.08126850326921842
# pi/4 is 0.7238095238095239
# Difference between actual value of pi/4 is 0.061588639587924376
# pi/4 is 0.8349206349206351
# Difference between actual value of pi/4 is -0.049522471523186784

# %%
pi_over_4 = madhava_series(1e-2)
# Out:
# pi/4 is 1
# Difference between actual value of pi/4 is -0.21460183660255172
# pi/4 is 0.6666666666666667
# Difference between actual value of pi/4 is 0.11873149673078154
# pi/4 is 0.8666666666666667
# Difference between actual value of pi/4 is -0.08126850326921842
# pi/4 is 0.7238095238095239
# Difference between actual value of pi/4 is 0.061588639587924376
# pi/4 is 0.8349206349206351
# Difference between actual value of pi/4 is -0.049522471523186784
# pi/4 is 0.7440115440115441
# Difference between actual value of pi/4 is 0.041386619385904155
# pi/4 is 0.8209346209346211
# Difference between actual value of pi/4 is -0.03553645753717283
# pi/4 is 0.7542679542679545
# Difference between actual value of pi/4 is 0.031130209129493824
# pi/4 is 0.8130914836797192
# Difference between actual value of pi/4 is -0.027693320282270895
# pi/4 is 0.7604599047323508
# Difference between actual value of pi/4 is 0.024938258665097468
# pi/4 is 0.8080789523513985
# Difference between actual value of pi/4 is -0.022680788953950204
# pi/4 is 0.7646006914818333
# Difference between actual value of pi/4 is 0.020797471915614985
# pi/4 is 0.8046006914818333
# Difference between actual value of pi/4 is -0.01920252808438505
# pi/4 is 0.7675636544447964
# Difference between actual value of pi/4 is 0.01783450895265193
# pi/4 is 0.802046413065486
# Difference between actual value of pi/4 is -0.016648249668037685
# pi/4 is 0.769788348549357
# Difference between actual value of pi/4 is 0.015609814848091319
# pi/4 is 0.8000913788523872
# Difference between actual value of pi/4 is -0.014693215454938957
# pi/4 is 0.7715199502809587
# Difference between actual value of pi/4 is 0.013878213116489624
# pi/4 is 0.7985469773079856
# Difference between actual value of pi/4 is -0.01314881391053735
# pi/4 is 0.77290595166696
# Difference between actual value of pi/4 is 0.012492211730488312
# pi/4 is 0.797296195569399
# Difference between actual value of pi/4 is -0.011898032171950734
# pi/4 is 0.7740403816159106
# Difference between actual value of pi/4 is 0.01135778178153768
# pi/4 is 0.7962626038381329
# Difference between actual value of pi/4 is -0.010864440440684575
# pi/4 is 0.774986008093452
# Difference between actual value of pi/4 is 0.010412155303996307
# pi/4 is 0.7953941713587581
# Difference between actual value of pi/4 is -0.009996007961309838
# pi/4 is 0.7757863282215032
# Difference between actual value of pi/4 is 0.009611835175945105
# pi/4 is 0.7946542527498051
# Difference between actual value of pi/4 is -0.009256089352356778
# pi/4 is 0.7764724345679869
# Difference between actual value of pi/4 is 0.00892572882946141
# pi/4 is 0.7940162942171096
# Difference between actual value of pi/4 is -0.00861813081966134
# pi/4 is 0.7770671416747368
# Difference between actual value of pi/4 is 0.008331021722711496
# pi/4 is 0.7934605842976876
# Difference between actual value of pi/4 is -0.008062420900239342
# pi/4 is 0.7775875684246718
# Difference between actual value of pi/4 is 0.0078105949727764745
# pi/4 is 0.7929721838092871
# Difference between actual value of pi/4 is -0.0075740204118388554
# pi/4 is 0.7780468106749587
# Difference between actual value of pi/4 is 0.007351352722489546
# pi/4 is 0.7925395642981471
# Difference between actual value of pi/4 is -0.007141400900698813
# pi/4 is 0.7784550572558936
# Difference between actual value of pi/4 is 0.006943106141554689
# pi/4 is 0.7921536873928798
# Difference between actual value of pi/4 is -0.006755523995431556
# pi/4 is 0.7788203540595465
# Difference between actual value of pi/4 is 0.006577809337901752
# pi/4 is 0.7918073670465595
# Difference between actual value of pi/4 is -0.006409203649111239
# pi/4 is 0.7791491391984583
# Difference between actual value of pi/4 is 0.006249024198989983
# pi/4 is 0.7914948182108039
# Difference between actual value of pi/4 is -0.00609665481335564
# pi/4 is 0.7794466254397195
# Difference between actual value of pi/4 is 0.005951537957728736
# pi/4 is 0.7912113313220724
# Difference between actual value of pi/4 is -0.005813167924624163
# pi/4 is 0.7797170784485092
# Difference between actual value of pi/4 is 0.005681084948939041
# pi/4 is 0.790953033504689
# Difference between actual value of pi/4 is -0.005554870107240761
# pi/4 is 0.7799640225156781
# Difference between actual value of pi/4 is 0.005434140881770189
# pi/4 is 0.7907167106877211
# Difference between actual value of pi/4 is -0.005318547290272813
# pi/4 is 0.7801903948982474
# Difference between actual value of pi/4 is 0.005207768499200904
# pi/4 is 0.7904996732487628
# Difference between actual value of pi/4 is -0.005101509851314523
# pi/4 is 0.7803986631477527
# Difference between actual value of pi/4 is 0.004999500249695532

# %% [markdown]
# We can't say our result is accurate to a tolerance of $10^{-n}$, since its the term after may change the value by rounding

# %%
def madhava_series2(tolerance):
    n = 1 
    value = 1
    newterm = tolerance*2
    
    while ((newterm**2)**.5) > tolerance:
        newterm = ((-1) ** n)/(2*n+1)
        print(f'pi/4 is {value}')
        print(f'The number of terms used is {n}') 
        value += newterm
        n += 1

# %%
# %%time
pi_over_four = madhava_series2(1e-1)
# Out:
# pi/4 is 1
# The number of terms used is 1
# pi/4 is 0.6666666666666667
# The number of terms used is 2
# pi/4 is 0.8666666666666667
# The number of terms used is 3
# pi/4 is 0.7238095238095239
# The number of terms used is 4
# pi/4 is 0.8349206349206351
# The number of terms used is 5
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
pi_over_four = madhava_series2(1e-2)
# Out:
# pi/4 is 1
# The number of terms used is 1
# pi/4 is 0.6666666666666667
# The number of terms used is 2
# pi/4 is 0.8666666666666667
# The number of terms used is 3
# pi/4 is 0.7238095238095239
# The number of terms used is 4
# pi/4 is 0.8349206349206351
# The number of terms used is 5
# pi/4 is 0.7440115440115441
# The number of terms used is 6
# pi/4 is 0.8209346209346211
# The number of terms used is 7
# pi/4 is 0.7542679542679545
# The number of terms used is 8
# pi/4 is 0.8130914836797192
# The number of terms used is 9
# pi/4 is 0.7604599047323508
# The number of terms used is 10
# pi/4 is 0.8080789523513985
# The number of terms used is 11
# pi/4 is 0.7646006914818333
# The number of terms used is 12
# pi/4 is 0.8046006914818333
# The number of terms used is 13
# pi/4 is 0.7675636544447964
# The number of terms used is 14
# pi/4 is 0.802046413065486
# The number of terms used is 15
# pi/4 is 0.769788348549357
# The number of terms used is 16
# pi/4 is 0.8000913788523872
# The number of terms used is 17
# pi/4 is 0.7715199502809587
# The number of terms used is 18
# pi/4 is 0.7985469773079856
# The number of terms used is 19
# pi/4 is 0.77290595166696
# The number of terms used is 20
# pi/4 is 0.797296195569399
# The number of terms used is 21
# pi/4 is 0.7740403816159106
# The number of terms used is 22
# pi/4 is 0.7962626038381329
# The number of terms used is 23
# pi/4 is 0.774986008093452
# The number of terms used is 24
# pi/4 is 0.7953941713587581
# The number of terms used is 25
# pi/4 is 0.7757863282215032
# The number of terms used is 26
# pi/4 is 0.7946542527498051
# The number of terms used is 27
# pi/4 is 0.7764724345679869
# The number of terms used is 28
# pi/4 is 0.7940162942171096
# The number of terms used is 29
# pi/4 is 0.7770671416747368
# The number of terms used is 30
# pi/4 is 0.7934605842976876
# The number of terms used is 31
# pi/4 is 0.7775875684246718
# The number of terms used is 32
# pi/4 is 0.7929721838092871
# The number of terms used is 33
# pi/4 is 0.7780468106749587
# The number of terms used is 34
# pi/4 is 0.7925395642981471
# The number of terms used is 35
# pi/4 is 0.7784550572558936
# The number of terms used is 36
# pi/4 is 0.7921536873928798
# The number of terms used is 37
# pi/4 is 0.7788203540595465
# The number of terms used is 38
# pi/4 is 0.7918073670465595
# The number of terms used is 39
# pi/4 is 0.7791491391984583
# The number of terms used is 40
# pi/4 is 0.7914948182108039
# The number of terms used is 41
# pi/4 is 0.7794466254397195
# The number of terms used is 42
# pi/4 is 0.7912113313220724
# The number of terms used is 43
# pi/4 is 0.7797170784485092
# The number of terms used is 44
# pi/4 is 0.790953033504689
# The number of terms used is 45
# pi/4 is 0.7799640225156781
# The number of terms used is 46
# pi/4 is 0.7907167106877211
# The number of terms used is 47
# pi/4 is 0.7801903948982474
# The number of terms used is 48
# pi/4 is 0.7904996732487628
# The number of terms used is 49
# pi/4 is 0.7803986631477527
# The number of terms used is 50
# CPU times: total: 0 ns
# Wall time: 1 ms

# %% [markdown]
# I can't say what the time would be for when we use a tolerance of $10^{-7}$ since just using $10^{-2}$ uses 50 terms compared to $10^{-1}$ using 5. I tried it but my computer went extremely slow and the list was way too long. Hence for part a, the values tried only were -1 and -2 since -7 would make the notebook extremely laggy when opening
# I tried it with $10^{-1}$ & $10^{-2}$ and had a wall time of 0ms and 2ms respectively. Based on this, would think 16 decimal places would take about 0.06ms and 32 decimal places would be 0.12 ms. I used simple fractions to estimate these. But it's worth noting that there is a big uncertainty in the times i got, hence the times I estimated.
# Overall, I think this is a great algorithm to calculate pi since its fairly simple, given that you have a powerful enough computer to withstand extremely low tolerance values.

# %% [markdown]
# ## References
#
# [1] Chislett C, Dash L and Waugh B. *PHAS0007 Unit 6: Functions and while loops: Defining a function to calculate the Madhava series
# .* [online] UCL: London; 2022 [Accessed 18 November 2022]. Available from: https://moodle.ucl.ac.uk/course/view.php?id=31674
